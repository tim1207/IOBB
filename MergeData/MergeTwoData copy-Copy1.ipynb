# %%
import serial
import csv
import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.fftpack import fft, ifft
import math

dataWalk = pd.read_csv("../220328走路加拿放資料59s/腳2022-03-28 222000.csv")
dataWalk = np.array(dataWalk)

dataTake= pd.read_csv("../220328走路加拿放資料59s/腳2022-03-28 222000.csv")
dataTake = np.array(dataTake)

lengthOfWalk=[]
for i in range(len(dataWalk[:,1])):
    lengthOfWalk.append(i)
lengthOfTake=[]
for i in range(len(dataTake[:,1])):
    lengthOfTake.append(i)

# %%
# show all data
plt.figure(figsize = (40, 15), dpi = 300, linewidth = 4)
plt.xlabel("time", fontsize = 40, labelpad = 20)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
# plt.plot(lengthOfWalk, dataWalk[:,1], color = 'r', label = "Xa")
plt.plot(lengthOfWalk, dataWalk[:,2], color = 'g', label = "Ya")
plt.plot(lengthOfWalk, dataWalk[:,3], color = 'b', label = "Za")
plt.legend(loc = "center left", fontsize = 20, bbox_to_anchor = (1, 0.5))
plt.show()

# show all data
plt.figure(figsize = (40, 15), dpi = 300, linewidth = 4)
plt.xlabel("time", fontsize = 40, labelpad = 20)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
# plt.plot(lengthOfTake, dataTake[:,7], color = 'r', label = "Xa")
plt.plot(lengthOfTake, dataTake[:,8], color = 'g', label = "Ya")
plt.plot(lengthOfTake, dataTake[:,9], color = 'b', label = "Za")
plt.legend(loc = "center left", fontsize = 20, bbox_to_anchor = (1, 0.5))
plt.show()

# %%
mergeIndex=7
start=0
dataLength=300
bigDataTake=[]
# for i in range (int((dataLength/len(dataTake[:,mergeIndex])))):
#     bigDataTake.append(dataTake[:,mergeIndex])
mergeData=np.append(dataWalk[start:start+dataLength,1],bigDataTake)
mergeData1=np.append(dataWalk[start:start+dataLength,2],bigDataTake)
mergeData2=np.append(dataWalk[start:start+dataLength,3],bigDataTake)
lengthOfMergeData=[]
for i in range(len(mergeData)):
    lengthOfMergeData.append(i)
# show all data
plt.figure(figsize = (40, 15), dpi = 300, linewidth = 4)
plt.xlabel("time", fontsize = 40, labelpad = 20)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
plt.plot(lengthOfMergeData, mergeData, color = 'r', label = "Xq")
plt.plot(lengthOfMergeData, mergeData1, color = 'g', label = "Yq")
plt.plot(lengthOfMergeData, mergeData2, color = 'b', label = "Zq")
plt.legend(loc = "center left", fontsize = 20, bbox_to_anchor = (1, 0.5))
plt.show()

# %%
plt.figure(figsize = (40, 15), dpi = 300, linewidth = 4)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
plt.ylabel('Frequency',fontsize = 30)
plt.xlabel('Time',fontsize = 30)
plt.title('Xq transfrom',fontsize = 30)  
plt.specgram(mergeData,Fs=1,NFFT=18,noverlap=17,cmap='plasma')
plt.colorbar()
plt.show()
plt.figure(figsize = (40, 15), dpi = 300, linewidth = 4)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
plt.ylabel('Frequency',fontsize = 30)
plt.xlabel('Time',fontsize = 30)
plt.title('Yq transfrom',fontsize = 30) 
plt.specgram(mergeData1,Fs=1,NFFT=18,noverlap=17,cmap='plasma')
plt.colorbar()
plt.show()
plt.figure(figsize = (40, 15), dpi = 300, linewidth = 4)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
plt.ylabel('Frequency',fontsize = 30)
plt.xlabel('Time',fontsize = 30)
plt.title('Zq transfrom',fontsize = 30) 
plt.specgram(mergeData2,Fs=1,NFFT=18,noverlap=17,cmap='plasma')
plt.colorbar()
plt.show()
