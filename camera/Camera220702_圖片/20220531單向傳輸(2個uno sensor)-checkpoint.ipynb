# %%
import serial
import csv
import time
import pandas as pd
from datetime import datetime, timedelta
from time import sleep
serialPort = serial.Serial(port='COM71', baudrate=38400, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)#HC-05-1
serialPort2 = serial.Serial(port='COM70', baudrate=38400, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)#HC-05-2
#115200 esp32

print("hello")
#/dev/cu.name
size = 1024
xg,yg,zg,mx,my,mz,xa,ya,za,xq,yq,zq,direc,mytime =[],[],[],[],[],[],[],[],[],[],[],[],[],[]
xg2,yg2,zg2,mx2,my2,mz2,xa2,ya2,za2,xq2,yq2,zq2,direc2,mytime2 =[],[],[],[],[],[],[],[],[],[],[],[],[],[]
Ttime=str(datetime.now())
print(Ttime)
print(Ttime[17::])
tt=0
TT=59
while(tt<=TT):
    data = serialPort.readline().decode('utf-8')
    data2 = serialPort2.readline().decode('utf-8')
    print(data)
    print(data2)
    data=data.split(',')
    data2=data2.split(',')
#     print(len(data),len(data2))
#     print(float(str(datetime.now())[17::]))
    if (float(str(datetime.now())[17::])< float(Ttime[17::])):      
        tt = float(Ttime[17::])+60-float(str(datetime.now())[17::] )
        if tt>=TT:
            break
    else:
        tt = -float(Ttime[17::])+float(str(datetime.now())[17::] )
        if tt>=TT:
            break
    if len(data)==16:
        xg.append(data[1])
        yg.append(data[2])
        zg.append(data[3])
        mx.append(data[4])
        my.append(data[5])
        mz.append(data[6])
        xa.append(data[7])
        ya.append(data[8])
        za.append(data[9])
        xq.append(data[10])
        yq.append(data[11])
        zq.append(data[12])
        direc.append(data[13])
        mytime.append(data[14])
    if len(data2)==16:
        xg2.append(data2[1])
        yg2.append(data2[2])
        zg2.append(data2[3])
        mx2.append(data2[4])
        my2.append(data2[5])
        mz2.append(data2[6])
        xa2.append(data2[7])
        ya2.append(data2[8])
        za2.append(data2[9])
        xq2.append(data2[10])
        yq2.append(data2[11])
        zq2.append(data2[12])
        direc2.append(data2[13])
        mytime2.append(data2[14])
        
pandasData={"Xg":xg,"Yg":yg,"Zg":zg,"Xm":mx,"Ym":my,"Zm":mz,"Xa":xa,"Ya":ya,"Za":za,"Xq":xq,"Yq":yq,"Zq":zq,"Direction":direc,"Time":mytime}
pandasData2={"Xg":xg2,"Yg":yg2,"Zg":zg2,"Xm":mx2,"Ym":my2,"Zm":mz2,"Xa":xa2,"Ya":ya2,"Za":za2,"Xq":xq2,"Yq":yq2,"Zq":zq2,"Direction":direc2,"Time":mytime2}
df = pd.DataFrame(pandasData)
df2= pd.DataFrame(pandasData2)
print(df)
print(df2)

df.to_csv('腳'+datetime.now().strftime('%Y-%m-%d %H%M%S')+'.csv')
df2.to_csv('手'+datetime.now().strftime('%Y-%m-%d %H%M%S')+'.csv')
serialPort.close()
serialPort2.close()
# Out:
# hello
# 2022-06-22 17:33:23.866613
# 23.866613
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.06,9.61,-0.00,0.03,0.12,0.99,140615,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.64,-0.00,0.03,0.12,0.99,140653,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.64,-0.00,0.03,0.12,0.99,140692,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,140729,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,140768,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.64,-0.00,0.03,0.12,0.99,140807,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,140846,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,140883,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,140921,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,140960,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,140999,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.06,9.61,-0.00,0.03,0.12,0.99,141039,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,141076,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,141115,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,141154,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,141192,
#
#
# ,0.00,0.00,0.00,22.75,5.38,25.19,-0.54,0.02,9.61,-0.00,0.03,0.12,0.99,141230,
#
#
