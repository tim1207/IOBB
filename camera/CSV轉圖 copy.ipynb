# %%
dataCSV=[
    # "./CSV圖圖/camera2022-07-01 231532.csv",
    # "./CSV圖圖/camera2022-07-01 232624.csv",
    # "./CSV圖圖/camera2022-07-01 232628.csv",
    # "./CSV圖圖/camera2022-07-01 232631.csv",
    # "./CSV圖圖/camera2022-07-01 232633.csv",
    # "./CSV圖圖/camera2022-07-01 232635.csv",
    # "./CSV圖圖/camera2022-07-01 232639.csv",
    # "./CSV圖圖/camera2022-07-01 232644.csv",
    # "./CSV圖圖/camera2022-07-01 232648.csv",
    # "./CSV圖圖/camera2022-07-01 232653.csv",
    # "./CSV圖圖/camera2022-07-01 232657.csv",
    # "./CSV圖圖/camera2022-07-01 232701.csv",
    
    "./CSV圖圖/camera2022-07-02 022151.csv",
    "./CSV圖圖/camera2022-07-02 005645.csv",
     "./CSV圖圖/camera2022-07-02 020017.csv",





]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import pyplot as plt


filename = "camera.csv"
# filename = "./CSV圖圖/camera2022-07-02 005645.csv"
data = pd.read_csv(filename)
data =np.array(data)
print(data.dtype)

plt.imshow(data, interpolation='nearest')
plt.show()
# Out:
# int64

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


filename = dataCSV[2]
data = pd.read_csv(filename)
data =np.array(data)
data = data.T
print(data.shape)
print(data.dtype)

plt.imshow(data, interpolation='nearest')
plt.show()
# Out:
# (321, 226)
# int64
