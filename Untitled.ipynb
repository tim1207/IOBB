# %%
import serial
import csv
import pandas as pd
from datetime import datetime
from time import sleep
serialPort = serial.Serial(port='COM7', baudrate=57600, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)
serialPort = serial.Serial2(port='COM7', baudrate=57600, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)
#/dev/cu.name
size = 1024
xg,yg,zg,mx,my,mz,xa,ya,za,xq,yq,zq,direc =[],[],[],[],[],[],[],[],[],[],[],[],[]
xg1,yg1,zg1,mx1,my1,mz1,xa1,ya1,za1,xq1,yq1,zq1,direc1 =[],[],[],[],[],[],[],[],[],[],[],[],[]
for i in range (0,500):
    serialPort.write("csdcsdc\n".encode('utf-8'))
#     sleep(1)
    data = serialPort.readline().decode('utf-8')
    print(data)
    data=data.split(',')
    if len(data)==14:
        mx.append(data[0])
        my.append(data[1])
        mz.append(data[2])
        xg.append(data[3])
        yg.append(data[4])
        zg.append(data[5])
        xa.append(data[6])
        ya.append(data[7])
        za.append(data[8])
        xq.append(data[9])
        yq.append(data[10])
        zq.append(data[11])
        direc.append(data[12])
for i in range (0,500):
    serialPort1.write("csdcsdc\n".encode('utf-8'))
#     sleep(1)
    data1 = serialPort1.readline().decode('utf-8')
    print(data1)
    data1=data1.split(',')
    if len(data)==14:
        mx1.append(data1[0])
        my1.append(data1[1])
        mz1.append(data1[2])
        xg1.append(data1[3])
        yg1.append(data1[4])
        zg1.append(data1[5])
        xa1.append(data1[6])
        ya1.append(data1[7])
        za1.append(data1[8])
        xq1.append(data1[9])
        yq1.append(data1[10])
        zq1.append(data1[11])
        direc1.append(data1[12])
        
pandasData={"Xg":xg,"Yg":yg,"Zg":zg,"Xm":mx,"Ym":my,"Zm":mz,"Xa":xa,"Ya":ya,"Za":za,"Xq":xq,"Yq":yq,"Zq":zq,"Direction":direc}
df = pd.DataFrame(pandasData)
print(df)
pandasData1={"Xg":xg1,"Yg":yg1,"Zg":zg1,"Xm":mx1,"Ym":my1,"Zm":mz1,"Xa":xa1,"Ya":ya1,"Za":za1,"Xq":xq1,"Yq":yq1,"Zq":zq1,"Direction":direc1}
df1 = pd.DataFrame(pandasData1)
print(df1)
df.to_csv('蹺蹺板'+datetime.now().strftime('%Y-%m-%d %H%M%S')+'.csv')
serialPort.close()
df1.to_csv('蹺蹺板'+datetime.now().strftime('%Y-%m-%d %H%M%S')+'.csv')
serialPort1.close()
