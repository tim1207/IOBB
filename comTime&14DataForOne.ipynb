# %%
import serial
import csv
import time
import pandas as pd
from datetime import datetime, timedelta
from time import sleep
serialPort = serial.Serial(port='/dev/cu.KWK', baudrate=115200, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)
# serialPort2 = serial.Serial(port='/dev/cu.Sensor', baudrate=115200, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)


#/dev/cu.name
size = 1024
comTime,xg,yg,zg,mx,my,mz,xa,ya,za,xq,yq,zq,direc,mytime =[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]
# comTime2,xg2,yg2,zg2,mx2,my2,mz2,xa2,ya2,za2,xq2,yq2,zq2,direc2,mytime2 =[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]
Ttime=str(datetime.now())
print(Ttime[17::])
tt=0
while(tt<=10):
    serialPort.write(bytes(datetime.now().strftime('%H:%M:%S')+"#", 'big5'))
#     serialPort2.write(bytes(datetime.now().strftime('%H:%M:%S')+"#", 'big5'))
    data = serialPort.readline().decode('utf-8')
#     data2 = serialPort2.readline().decode('utf-8')
    print(data)
#     print(data2)
    data=data.split(',')
#     data2=data2.split(',')
    
    if (float(str(datetime.now())[17::])< float(Ttime[17::])):      
        tt = float(Ttime[17::])+60-float(str(datetime.now())[17::] )
        if tt>=10:
            break
    else:
        tt = -float(Ttime[17::])+float(str(datetime.now())[17::] )
        if tt>=10:
            break
    if len(data)==16:
        comTime.append(data[0])
        
        xg.append(data[1])
        yg.append(data[2])
        zg.append(data[3])
        mx.append(data[4])
        my.append(data[5])
        mz.append(data[6])
        xa.append(data[7])
        ya.append(data[8])
        za.append(data[9])
        xq.append(data[10])
        yq.append(data[11])
        zq.append(data[12])
        direc.append(data[13])
        mytime.append(data[14])
#     if len(data2)==16:
#         comTime2.append(data[0])

#         xg2.append(data[1])
#         yg2.append(data[2])
#         zg2.append(data[3])
#         mx2.append(data[4])
#         my2.append(data[5])
#         mz2.append(data[6])
#         xa2.append(data[7])
#         ya2.append(data[8])
#         za2.append(data[9])
#         xq2.append(data[10])
#         yq2.append(data[11])
#         zq2.append(data[12])
#         direc2.append(data[13])
#         mytime2.append(data[14])
        
pandasData={"Xg":xg,"Yg":yg,"Zg":zg,"Xm":mx,"Ym":my,"Zm":mz,"Xa":xa,"Ya":ya,"Za":za,"Xq":xq,"Yq":yq,"Zq":zq,"Direction":direc,"Time":mytime,"COMTime":comTime}
# pandasData2={"Xg":xg2,"Yg":yg2,"Zg":zg2,"Xm":mx2,"Ym":my2,"Zm":mz2,"Xa":xa2,"Ya":ya2,"Za":za2,"Xq":xq2,"Yq":yq2,"Zq":zq2,"Direction":direc2,"Time":mytime2,"COMTime":comTime2}
df = pd.DataFrame(pandasData)
# df2= pd.DataFrame(pandasData2)
print(df)
# print(df2)
df.to_csv('ComTime&14data'+datetime.now().strftime('%Y-%m-%d %H%M%S')+'.csv')
# df2.to_csv('ComTime&14data2'+datetime.now().strftime('%Y-%m-%d %H%M%S')+'.csv')
serialPort.close()
# serialPort2.close()
# Out:
# 07.181673
# 10:23:07,0.00,0.00,0.00,11.38,4.94,-19.12,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,592246,
#
# 10:23:08,0.00,0.00,0.00,11.38,4.94,-19.12,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,592843,
#
# 10:23:10,0.00,0.00,0.00,11.13,5.37,-16.81,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,594575,
#
# 10:23:10,
# 0.00,0.00,0.00,10.75,8.19,-14.25,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,595012,
#
# 10:23:12,0.00,0.00,0.00,10.75,8.19,-14.25,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,597056,
#
# 10:23:14,0.00,0.00,0.00,10.75,8.19,-14.25,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,598695,
#
# 10:23:14,0.00,0.00,0.00,10.94,4.56,-18.44,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,598703,
#
# 10:23:14,0.00,0.00,0.00,10.94,4.56,-18.44,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,598740,
#
# 10:23:14,0.00,0.00,0.00,10.94,4.56,-18.44,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,598757,
#
# 10:23:14,0.00,0.00,0.00,10.94,4.56,-18.44,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,598771,
#
# 10:23:14,0.00,0.00,0.00,10.94,4.56,-18.44,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,598780,
#
# 10:23:14,0.00,0.00,0.00,10.94,4.56,-18.44,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,598797,
#
# 10:23:1410:23:14,0.00,0.00,0.00,10.94,4.56,-18.44,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,598817,
#
# 10:23:14,0.00,0.00,0.00,10.94,4.56,-18.44,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,598837,
#
# 10:23:14,0.00,0.00,0.00,10.94,4.56,-18.44,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,598860,
#
# 10:23:14,0.00,0.00,0.00,10.94,4.56,-18.44,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,598882,
#
# 10:23:14,0.00,0.00,0.00,12.06,2.69,-17.69,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,598903,
#
# 10:23:14,0.00,0.00,0.00,12.06,2.69,-17.69,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,598925,
#
# 10:23:14,0.00,0.00,0.00,12.06,2.69,-17.69,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,598950,
#
# 10:23:14,0.00,0.00,0.00,12.06,2.69,-17.69,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,598972,
#
# 10:23:14,0.00,0.00,0.00,12.06,2.69,-17.69,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599002,
#
# 10:23:14,0.00,0.00,0.00,12.06,2.69,-17.69,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599024,
#
# 10:23:14,0.00,0.00,0.00,12.06,2.69,-17.69,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599049,
#
# 10:23:14,0.00,0.00,0.00,12.06,2.69,-17.69,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599072,
#
# 10:23:14,0.00,0.00,0.00,12.06,2.69,-17.69,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599095,
#
# 10:23:14,0.00,0.00,0.00,12.06,2.69,-17.69,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599111,
#
# 10:23:14,0.00,0.00,0.00,12.06,2.69,-17.69,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599134,
#
# 10:23:14,0.00,0.00,0.00,11.69,3.37,-18.37,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599153,
#
# 10:23:14,0.00,0.00,0.00,11.69,3.37,-18.37,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599178,
#
# 10:23:14,0.00,0.00,0.00,11.69,3.37,-18.37,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599199,
#
# 10:23:14,0.00,0.00,0.00,11.69,3.37,-18.37,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599230,
#
# 10:23:14,0.00,0.00,0.00,11.69,3.37,-18.37,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599270,
#
# 10:23:14,0.00,0.00,0.00,11.69,3.37,-18.37,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599291,
#
# 10:23:14,0.00,0.00,0.00,11.69,3.37,-18.37,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599310,
#
# 10:23:14,0.00,0.00,0.00,11.69,3.37,-18.37,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599335,
#
# 10:23:14,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599357,
#
# 10:23:14,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599382,
#
# 10:23:14,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599404,
#
# 10:23:14,0.00,0.00,0.00,11.50,2.94,-19.00,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599427,
#
# 10:23:14,0.00,0.00,0.00,11.50,2.94,-19.00,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599451,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599474,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599497,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599527,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599553,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599574,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599597,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599618,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599640,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599663,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599741,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599763,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599786,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599834,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599861,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599884,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599907,
#
# 10:23:15,0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599928,
#
# 10:23:15,0.01,-0.02,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,599953,
#
# 10:23:15,0.01,-0.02,0.00,11.50,2.94,-19.00,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599975,
#
# 10:23:15,-0.01,0.03,0.00,11.50,2.94,-19.00,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,599998,
#
# 10:23:15,-0.01,0.03,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600041,
#
# 10:23:15,-0.00,0.00,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600079,
#
# 10:23:15,0.01,-0.01,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600103,
#
# 10:23:15,0.01,-0.01,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600121,
#
# 10:23:15,0.00,0.00,-0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600141,
#
# 10:23:15,0.00,0.00,-0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600167,
#
# 10:23:15,0.00,0.00,-0.00,11.50,2.94,-19.00,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600196,
#
# 10:23:15,0.00,0.00,-0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600217,
#
# 10:23:15,0.00,-0.01,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600239,
#
# 10:23:15,0.00,-0.01,0.00,11.50,2.94,-19.00,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600264,
#
# 10:23:15,0.00,-0.01,0.00,11.50,2.94,-19.00,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600289,
#
# 10:23:15,0.00,-0.01,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600313,
#
# 10:23:15,0.00,-0.00,0.00,11.50,2.94,-19.00,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600333,
#
# 10:23:15,0.00,-0.00,0.00,11.38,4.94,-19.44,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600358,
#
# 10:23:15,0.00,-0.00,0.00,11.38,4.94,-19.44,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600380,
#
# 10:23:15,0.00,0.00,0.00,11.38,4.94,-19.44,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600404,
#
# 10:23:15,0.00,-0.00,-0.00,11.38,4.94,-19.44,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600427,
#
# 10:23:15,0.00,-0.00,-0.00,11.38,4.94,-19.44,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600453,
#
# 10:23:16,0.00,-0.00,-0.00,11.38,4.94,-19.44,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600475,
#
# 10:23:16,-0.00,-0.00,-0.00,11.38,4.94,-19.44,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600500,
#
# 10:23:16,-0.00,-0.00,-0.00,11.38,4.94,-19.44,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600555,
#
# 10:23:16,0.00,0.01,0.00,11.38,4.94,-19.44,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600592,
#
# 10:23:16,0.01,-0.04,0.00,11.38,4.94,-19.44,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600614,
#
# 10:23:16,0.01,-0.04,0.00,11.38,4.94,-19.44,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600634,
#
# 10:23:16,0.01,-0.04,0.00,10.94,4.62,-19.12,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600658,
#
# 10:23:16,0.01,-0.04,0.00,10.94,4.62,-19.12,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600711,
#
# 10:23:16,0.00,0.01,-0.00,10.94,4.62,-19.12,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600738,
#
# 10:23:16,0.00,-0.01,0.00,10.94,4.62,-19.12,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600763,
#
# 10:23:16,0.00,-0.01,0.00,10.94,4.62,-19.12,0.19,-0.18,9.72,-0.01,-0.00,-0.52,0.85,600788,
#
# 10:23:16,-0.00,0.00,0.00,10.94,4.62,-19.12,0.19,-0.18,9.72,-0.01,-0.00,-0.52,0.85,600812,
#
# 10:23:16,-0.00,0.00,0.00,10.94,4.62,-19.12,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600831,
#
# 10:23:16,0.00,0.00,0.00,10.94,4.62,-19.12,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,600915,
#
# 10:23:16,0.00,0.00,0.00,10.94,4.62,-19.12,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600942,
#
# 10:23:16,0.00,0.00,0.00,10.81,5.12,-19.50,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,600988,
# 10:23:16,0.00,0.00,0.00,10.81,5.12,-19.50,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601013,
#
# 10:23:16,-0.01,0.04,-0.00,10.81,5.12,-19.50,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601038,
#
# 10:23:16,-0.01,0.04,-0.00,10.81,5.12,-19.50,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601061,
#
# 10:23:16,-0.01,0.04,-0.00,10.81,5.12,-19.50,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601084,
#
# 10:23:16,0.01,-0.02,-0.00,10.81,5.12,-19.50,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601107,
#
# 10:23:16,0.01,-0.02,-0.00,10.81,5.12,-19.50,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,601130,
#
# 10:23:16,0.00,-0.01,-0.00,10.81,5.12,-19.50,0.23,-0.18,9.68,-0.01,-0.00,-0.52,0.85,601155,
#
# 10:23:16,0.00,-0.01,-0.00,10.81,5.12,-19.50,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601177,
#
# 10:23:16,0.00,0.01,-0.00,10.81,5.12,-19.50,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601229,
#
# 10:23:16,0.00,0.01,-0.00,10.81,5.12,-19.50,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,601250,
#
# 10:23:16,0.00,0.01,-0.00,10.81,5.12,-19.50,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,601273,
#
# 10:23:16,0.00,-0.00,-0.00,10.81,5.12,-19.50,0.19,-0.18,9.68,-0.01,-0.00,-0.52,0.85,601293,
#
# 10:23:16,0.00,-0.00,-0.00,10.81,5.12,-19.50,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601320,
#
# 10:23:16,0.00,0.00,-0.00,10.81,5.12,-19.50,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601378,
#
# 10:23:16,0.00,0.00,-0.00,10.81,5.12,-19.50,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601402,
#
# 10:23:16,0.00,0.00,-0.00,10.81,5.12,-19.50,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601424,
#
# 10:23:16,0.00,0.00,0.00,10.81,5.12,-19.50,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601450,
#
# 10:23:17,0.00,0.00,0.00,10.81,5.12,-19.50,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601469,
#
# 10:23:17,0.00,0.00,0.00,10.81,5.12,-19.50,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601500,
#
# 10:23:17,0.00,0.00,0.00,10.81,5.12,-19.50,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601532,
#
# 10:23:17,0.01,-0.03,0.00,10.81,5.12,-19.50,0.19,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601555,
#
# 10:23:17,0.01,-0.03,0.00,10.81,5.12,-19.50,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601575,
#
# 10:23:17,0.00,-0.01,0.00,10.81,5.12,-19.50,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601599,
#
# 10:23:17,0.00,-0.01,0.00,10.81,5.12,-19.50,0.23,-0.21,9.68,-0.01,-0.00,-0.52,0.85,601624,
#
#         Xg    Yg      Zg    Xm     Ym    Zm    Xa     Ya    Za     Xq     Yq  \
# 0    11.38  4.94  -19.12  0.00   0.00  0.00  0.23  -0.18  9.68  -0.01  -0.00
# 1    11.38  4.94  -19.12  0.00   0.00  0.00  0.23  -0.18  9.68  -0.01  -0.00
# 2    11.13  5.37  -16.81  0.00   0.00  0.00  0.23  -0.18  9.68  -0.01  -0.00
# 3    10.75  8.19  -14.25  0.00   0.00  0.00  0.19  -0.21  9.68  -0.01  -0.00
# 4    10.75  8.19  -14.25  0.00   0.00  0.00  0.23  -0.18  9.68  -0.01  -0.00
# ..     ...   ...     ...   ...    ...   ...   ...    ...   ...    ...    ...
# 111  10.81  5.12  -19.50  0.00   0.00  0.00  0.23  -0.21  9.68  -0.01  -0.00
# 112  10.81  5.12  -19.50  0.00   0.00  0.00  0.19  -0.21  9.68  -0.01  -0.00
# 113  10.81  5.12  -19.50  0.01  -0.03  0.00  0.19  -0.21  9.68  -0.01  -0.00
# 114  10.81  5.12  -19.50  0.01  -0.03  0.00  0.23  -0.21  9.68  -0.01  -0.00
# 115  10.81  5.12  -19.50  0.00  -0.01  0.00  0.23  -0.21  9.68  -0.01  -0.00
#
#         Zq Direction    Time   COMTime
# 0    -0.52      0.85  592246  10:23:07
# 1    -0.52      0.85  592843  10:23:08
# 2    -0.52      0.85  594575  10:23:10
# 3    -0.52      0.85  597056  10:23:12
# 4    -0.52      0.85  598695  10:23:14
# ..     ...       ...     ...       ...
# 111  -0.52      0.85  601500  10:23:17
# 112  -0.52      0.85  601532  10:23:17
# 113  -0.52      0.85  601555  10:23:17
# 114  -0.52      0.85  601575  10:23:17
# 115  -0.52      0.85  601599  10:23:17
#
# [116 rows x 15 columns]
